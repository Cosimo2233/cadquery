# %%
import sys
sys.path.append(r"D:\workspace\quarry_cad\cadquery_models\pt01")  # part_01.py 所在目录

import cadquery as cq
from jupyter_cadquery import show, set_defaults
from part_01 import build

# 设置默认可视化
set_defaults(axes=True, grid=None)  # 或 grid=(10,10,10)

# 生成模型
result = build()

# 显示
show(result)
# Out:
# c
# CadViewerWidget(anchor=None, aspect_ratio=0.75, cad_width=800, control='trackball', glass=True, height=600, id…
# <div></div>
