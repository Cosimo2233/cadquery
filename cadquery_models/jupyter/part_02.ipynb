# %%
import sys
sys.path.append(r"D:\\workspace\\quarry_cad\\cadquery_models\\pt01")  # part script directory

import cadquery as cq
from jupyter_cadquery import show, set_defaults
from part_02 import build

# 设置默认可视化
set_defaults(axes=True, grid=None)  # or grid=(10,10,10)

# 生成模型
result = build()

# 显示
show(result)
# Out:
# Overwriting auto display for cadquery Workplane and Shape
# +
# D:\workspace\quarry_cad\.venv\Lib\site-packages\cad_viewer_widget\utils.py:117: PyparsingDeprecationWarning: 'delimitedList' deprecated - use 'DelimitedList'
#   index = lbrack + delimitedList(integer) + rbrack
# CadViewerWidget(anchor=None, aspect_ratio=0.75, cad_width=800, control='trackball', glass=True, height=600, id…
# <div></div>
