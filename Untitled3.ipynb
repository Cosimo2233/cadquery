# %%
# !pip install cadquery
# Out:
# Requirement already satisfied: cadquery in d:\workspace\quarry_cad\.venv\lib\site-packages (2.7.0)
# Requirement already satisfied: cadquery-ocp<7.9,>=7.8.1 in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (7.8.1.1.post1)
# Requirement already satisfied: ezdxf>=1.3.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (1.4.4)
# Requirement already satisfied: multimethod<2.0,>=1.11 in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (1.12)
# Requirement already satisfied: nlopt<3.0,>=2.9.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (2.10.0)
# Requirement already satisfied: runtype in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (0.5.3)
# Requirement already satisfied: casadi in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (3.7.2)
# Requirement already satisfied: path in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (17.1.1)
# Requirement already satisfied: trame in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (3.13.2)
# Requirement already satisfied: trame-vtk in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (2.11.8)
# Requirement already satisfied: trame-components in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (2.5.0)
# Requirement already satisfied: trame-vuetify in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (3.2.2)
# Requirement already satisfied: pyparsing>=3.0.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery) (3.3.2)
# Requirement already satisfied: vtk==9.3.1 in d:\workspace\quarry_cad\.venv\lib\site-packages (from cadquery-ocp<7.9,>=7.8.1->cadquery) (9.3.1)
# Requirement already satisfied: matplotlib>=2.0.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (3.10.9)
# Requirement already satisfied: typing_extensions>=4.6.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from ezdxf>=1.3.0->cadquery) (4.15.0)
# Requirement already satisfied: numpy in d:\workspace\quarry_cad\.venv\lib\site-packages (from ezdxf>=1.3.0->cadquery) (2.4.6)
# Requirement already satisfied: fonttools in d:\workspace\quarry_cad\.venv\lib\site-packages (from ezdxf>=1.3.0->cadquery) (4.63.0)
# Requirement already satisfied: trame-server<4,>=3.12.2 in d:\workspace\quarry_cad\.venv\lib\site-packages (from trame->cadquery) (3.12.4)
# Requirement already satisfied: trame-client<4,>=3.12.2 in d:\workspace\quarry_cad\.venv\lib\site-packages (from trame->cadquery) (3.12.3)
# Requirement already satisfied: trame-common<2,>=1.2.3 in d:\workspace\quarry_cad\.venv\lib\site-packages (from trame->cadquery) (1.2.3)
# Requirement already satisfied: wslink>=2.5.6 in d:\workspace\quarry_cad\.venv\lib\site-packages (from trame->cadquery) (2.5.7)
# Requirement already satisfied: pyyaml in d:\workspace\quarry_cad\.venv\lib\site-packages (from trame->cadquery) (6.0.3)
# Requirement already satisfied: more-itertools in d:\workspace\quarry_cad\.venv\lib\site-packages (from trame-server<4,>=3.12.2->trame->cadquery) (11.1.0)
# Requirement already satisfied: aiohttp<4 in d:\workspace\quarry_cad\.venv\lib\site-packages (from wslink>=2.5.6->trame->cadquery) (3.14.0)
# Requirement already satisfied: msgpack<2,>=1 in d:\workspace\quarry_cad\.venv\lib\site-packages (from wslink>=2.5.6->trame->cadquery) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from aiohttp<4->wslink>=2.5.6->trame->cadquery) (1.24.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\workspace\quarry_cad\.venv\lib\site-packages (from matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\workspace\quarry_cad\.venv\lib\site-packages (from matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\workspace\quarry_cad\.venv\lib\site-packages (from matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (26.2)
# Requirement already satisfied: pillow>=8 in d:\workspace\quarry_cad\.venv\lib\site-packages (from matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (12.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\workspace\quarry_cad\.venv\lib\site-packages (from matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\workspace\quarry_cad\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk==9.3.1->cadquery-ocp<7.9,>=7.8.1->cadquery) (1.17.0)
# Requirement already satisfied: idna>=2.0 in d:\workspace\quarry_cad\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4->wslink>=2.5.6->trame->cadquery) (3.18)
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from __future__ import annotations
import cadquery as cq
# 关键修改：直接从 cadquery.vis 导入 show 函数
from cadquery.vis import show

SIZE = 50.0
HEIGHT = 22.0
TOP_THICKNESS = 4.0
LEG_THICKNESS = 5.0
LEG_DEPTH = HEIGHT - TOP_THICKNESS

def build() -> cq.Workplane:
    top = (
        cq.Workplane("XY")
        .rect(SIZE, SIZE)
        .extrude(TOP_THICKNESS * 0.5, both=True)
        .translate((0, 0, HEIGHT * 0.5 - TOP_THICKNESS * 0.5))
    )
    for x, y, length, diameter in [
        (-11.0, 4.0, 18.0, 8.0),
        (9.0, 12.0, 16.0, 7.0),
        (10.0, 0.0, 16.0, 7.0),
        (10.0, -12.0, 16.0, 7.0),
    ]:
        top = top.cut(cq.Workplane("XY").center(x, y).slot2D(length, diameter, 90 if x < 0 else 0).extrude(TOP_THICKNESS * 2.5, both=True))
    legs = cq.Workplane("XY")
    for x in [-SIZE * 0.5 + LEG_THICKNESS * 0.5, SIZE * 0.5 - LEG_THICKNESS * 0.5]:
        legs = legs.union(
            cq.Workplane("XY")
            .center(x, 0)
            .rect(LEG_THICKNESS, SIZE * 0.88)
            .extrude(LEG_DEPTH)
            .translate((0, 0, HEIGHT * 0.5 - TOP_THICKNESS - LEG_DEPTH))
        )
    front_rib = (
        cq.Workplane("XZ")
        .polyline([(-SIZE * 0.4, 0), (SIZE * 0.4, 0), (0, -LEG_DEPTH * 0.45)])
        .close()
        .extrude(3.0, both=True)
        .translate((0, -SIZE * 0.18, 3.0))
    )
    back_rib = front_rib.translate((0, SIZE * 0.36, 0))
    return top.union(legs).union(front_rib).union(back_rib)

# 生成模型并显示
result = build()
show(result)
